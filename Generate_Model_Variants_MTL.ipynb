# %%
import torch
import torchvision
from torch.utils.data import DataLoader, Dataset, random_split
from torch import nn
from torch.nn.utils import prune
import numpy as np
import sys
import matplotlib.pyplot as plt
import math
import random
import sklearn.metrics as perf
import os
import cv2
import time
import torch_pruning as tp
import csv

from models.models import MTLClassifier, AgeRegressor, GenderClassifier, EthnicityClassifier
from utils.data import FacesDataset, data_transform
from utils.training import train_mtl_model, train_age_model, train_gender_model, train_ethnicity_model, train_mtl_model_individual
from utils.evaluation import run_evaluation, show_example_predictions
from utils.pruning import prune_model, prune_other_tasks, get_f1_and_lat

# %% [markdown]
# ### Load and Prepare Data

# %%
### Load in the data
folder = 'UTKFace'
transform = data_transform()
dataset = FacesDataset(folder=folder, transform=transform)

# %%
### Set up train and val datasets and loaders
train_len = int(len(dataset)*0.8)
val_len = len(dataset) - train_len
train_dataset, val_dataset = random_split(dataset, [train_len, val_len], torch.Generator().manual_seed(8))

train_loader = DataLoader(dataset=train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=16, shuffle=False)

# %%
### Get small subset fpr train_loader and val_loader (for testing and debugging)
# train_indices = torch.randperm(len(train_dataset))[:100]
# val_indices = torch.randperm(len(val_dataset))[:100]
# train_subset = torch.utils.data.Subset(train_dataset, train_indices)
# val_subset = torch.utils.data.Subset(val_dataset, val_indices)
# train_loader = DataLoader(dataset=train_subset, batch_size=16, shuffle=True)
# val_loader = DataLoader(dataset=val_subset, batch_size=16, shuffle=True)

# %% [markdown]
# ### MTL Model Variants

# %% [markdown]
# #### Define pruned training function

# %%
def pruned_mtl_training(task, prune_pct, num_epochs,
                        train_loader=train_loader, val_loader=val_loader,
                        val_dataset=None):
    
    ### Set up model, loss, and optimizer
    if task.upper()=='ALL':
        tasks = ['age', 'gender', 'ethnicity']
        model = MTLClassifier()
        model = model.cuda()
        age_criterion = nn.MSELoss()
        gender_criterion = nn.CrossEntropyLoss()
        ethnicity_criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(model.parameters())

        # Set up and run model training
        age_coeff = 0.004
        gender_coeff = 2
        ethnicity_coeff = 1
        
        # Train initial model
        print('---------------- Train Initial Model ----------------')
        save_no_prune = f'model_variants/{task.lower()}_p-0_lat-init_f1-init_MTLModel.pth'
        train_mtl_model(num_epochs=num_epochs, model=model, optimizer=optimizer,
                        train_loader=train_loader, val_loader=val_loader,
                        age_criterion=age_criterion, gender_criterion=gender_criterion, ethnicity_criterion=ethnicity_criterion,
                        age_coeff=age_coeff, gender_coeff=gender_coeff, ethnicity_coeff=ethnicity_coeff, save=True,
                        save_name=save_no_prune)
        
        # Do pruning
        model = torch.load(f'models/{save_no_prune}')
        pruned_model = prune_model(model, PRUNING_PERCENT=prune_pct)
        pruned_optimizer = torch.optim.Adam(pruned_model.parameters())
        
        # Fine-tune model
        print('-------------- Fine-tuning Pruned Model -------------')
        save_initial = f'model_variants/{task.lower()}_p-{int(prune_pct*100)}_lat-init_f1-init_MTLModel.pth'
        train_mtl_model(num_epochs=num_epochs, model=pruned_model, optimizer=pruned_optimizer,
                        train_loader=train_loader, val_loader=val_loader,
                        age_criterion=age_criterion, gender_criterion=gender_criterion, ethnicity_criterion=ethnicity_criterion,
                        age_coeff=age_coeff, gender_coeff=gender_coeff, ethnicity_coeff=ethnicity_coeff, save=True,
                        save_name=save_initial)
        
        # Test latency and accuracy (F1) and save model variant (and update lookup file)
        [scores, [mean_lat, std_lat]] = get_f1_and_lat(model_path=save_initial,
                                                   eval_dataset=val_dataset,
                                                   eval_dataloader=val_loader,
                                                   tasks=tasks,
                                                   mtl_model=True)
        
        # Save model with score and latency information in the model name
        ager2 = scores['age'][1]
        genderf1 = scores['gender'][0]
        ethnicityf1 = scores['ethnicity'][0]
        row = [task.upper(), prune_pct, mean_lat, std_lat, ager2, genderf1, ethnicityf1]
        with open('models/model_variants/model_score_lookup_multitask.tsv', 'a', newline='') as f:
            writer = csv.writer(f, delimiter='\t')
            writer.writerow(row)
            
        new_name = f'model_variants/{task.lower()}_p-{int(prune_pct*100)}_MTLModel.pth'
        torch.save(model, f"models/{new_name}")
        
        
    elif task.upper()=='GENDER':
        tasks = ['gender']
        model = MTLClassifier()
        model = model.cuda()
        age_criterion = nn.MSELoss()
        gender_criterion = nn.CrossEntropyLoss()
        ethnicity_criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(model.parameters())

        # Set up and run model training
        age_coeff = 0.004
        gender_coeff = 2
        ethnicity_coeff = 1
        
        # Train initial model
        print('---------------- Train Initial Model ----------------')
        save_no_prune = f'model_variants/{task.lower()}_p-0_lat-init_f1-init_MTLModel.pth'
        train_mtl_model(num_epochs=num_epochs, model=model, optimizer=optimizer,
                        train_loader=train_loader, val_loader=val_loader,
                        age_criterion=age_criterion, gender_criterion=gender_criterion, ethnicity_criterion=ethnicity_criterion,
                        age_coeff=age_coeff, gender_coeff=gender_coeff, ethnicity_coeff=ethnicity_coeff, save=True,
                        save_name=save_no_prune)
        
        # Do pruning
        model = torch.load(f'models/{save_no_prune}')
        pruned_model = prune_other_tasks(model, task1='age', task2='ethnicity', PRUNING_PERCENT=prune_pct)
        pruned_optimizer = torch.optim.Adam(pruned_model.parameters())
        
        # Fine-tune model
        print('-------------- Fine-tuning Pruned Model -------------')
        save_initial = f'model_variants/{task.lower()}_p-{int(prune_pct*100)}_lat-init_f1-init_MTLModel.pth'
        train_mtl_model_individual(num_epochs=num_epochs, model=pruned_model, optimizer=pruned_optimizer,
                              train_loader=train_loader, val_loader=val_loader,
                              gender_criterion=gender_criterion, age_coeff=1.0, gender_coeff=1.0, ethnicity_coeff=1.0,
                              save=True, save_name=save_initial, isGender=True)
        
        # Test latency and accuracy (F1) and save model variant (and update lookup file)
        [scores, [mean_lat, std_lat]] = get_f1_and_lat(model_path=save_initial,
                                                   eval_dataset=val_dataset,
                                                   eval_dataloader=val_loader,
                                                   tasks=tasks,
                                                   mtl_model=True)
        
        # Save model with score and latency information in the model name
        genderf1 = scores['gender'][0]
        row = [task.upper(), prune_pct, mean_lat, std_lat, 0.0, genderf1, 0.0]
        with open('models/model_variants/model_score_lookup_multitask.tsv', 'a', newline='') as f:
            writer = csv.writer(f, delimiter='\t')
            writer.writerow(row)
            
        new_name = f'model_variants/{task.lower()}_p-{int(prune_pct*100)}_MTLModel.pth'
        torch.save(model, f"models/{new_name}")
        
    elif task.upper()=='ETHNICITY':
        tasks = ['ethnicity']
        model = MTLClassifier()
        model = model.cuda()
        age_criterion = nn.MSELoss()
        gender_criterion = nn.CrossEntropyLoss()
        ethnicity_criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(model.parameters())

        # Set up and run model training
        age_coeff = 0.004
        gender_coeff = 2
        ethnicity_coeff = 1
        
        
        # Train initial model
        print('---------------- Train Initial Model ----------------')
        save_no_prune = f'model_variants/{task.lower()}_p-0_lat-init_f1-init_MTLModel.pth'
        train_mtl_model(num_epochs=num_epochs, model=model, optimizer=optimizer,
                        train_loader=train_loader, val_loader=val_loader,
                        age_criterion=age_criterion, gender_criterion=gender_criterion, ethnicity_criterion=ethnicity_criterion,
                        age_coeff=age_coeff, gender_coeff=gender_coeff, ethnicity_coeff=ethnicity_coeff, save=True,
                        save_name=save_no_prune)
        
        # Do pruning
        model = torch.load(f'models/{save_no_prune}')
        pruned_model = prune_other_tasks(model, task1='age', task2='gender', PRUNING_PERCENT=prune_pct)
        pruned_optimizer = torch.optim.Adam(pruned_model.parameters())
        
        # Fine-tune model
        print('-------------- Fine-tuning Pruned Model -------------')
        save_initial = f'model_variants/{task.lower()}_p-{int(prune_pct*100)}_lat-init_f1-init_MTLModel.pth'
        train_mtl_model_individual(num_epochs=num_epochs, model=pruned_model, optimizer=pruned_optimizer,
                              train_loader=train_loader, val_loader=val_loader,
                              ethnicity_criterion=ethnicity_criterion, age_coeff=1.0, gender_coeff=1.0, ethnicity_coeff=1.0,
                              save=True, save_name=save_initial, isethnicity=True)
        
        # Test latency and accuracy (F1) and save model variant (and update lookup file)
        [scores, [mean_lat, std_lat]] = get_f1_and_lat(model_path=save_initial,
                                                       eval_dataset=val_dataset,
                                                       eval_dataloader=val_loader,
                                                       tasks=tasks,
                                                       mtl_model=True)
        
        # Save model with score and latency information in the model name
        ethnicityf1 = scores['ethnicity'][0]
        row = [task.upper(), prune_pct, mean_lat, std_lat, 0.0, 0.0, ethnicityf1]
        with open('models/model_variants/model_score_lookup_multitask.tsv', 'a', newline='') as f:
            writer = csv.writer(f, delimiter='\t')
            writer.writerow(row)
            
        new_name = f'model_variants/{task.lower()}_p-{int(prune_pct*100)}_MTLModel.pth'
        torch.save(model, f"models/{new_name}")
        
    elif task.upper()=='AGE':
        tasks = ['age']
        model = MTLClassifier()
        model = model.cuda()
        age_criterion = nn.MSELoss()
        gender_criterion = nn.CrossEntropyLoss()
        ethnicity_criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(model.parameters())

        # Set up and run model training
        age_coeff = 0.004
        gender_coeff = 2
        ethnicity_coeff = 1
        
        
        # Train initial model
        print('---------------- Train Initial Model ----------------')
        save_no_prune = f'model_variants/{task.lower()}_p-0_lat-init_f1-init_MTLModel.pth'
        train_mtl_model(num_epochs=num_epochs, model=model, optimizer=optimizer,
                        train_loader=train_loader, val_loader=val_loader,
                        age_criterion=age_criterion, gender_criterion=gender_criterion, ethnicity_criterion=ethnicity_criterion,
                        age_coeff=age_coeff, gender_coeff=gender_coeff, ethnicity_coeff=ethnicity_coeff, save=True,
                        save_name=save_no_prune)
        
        # Do pruning
        model = torch.load(f'models/{save_no_prune}')
        pruned_model = prune_other_tasks(model, task1='gender', task2='ethnicity', PRUNING_PERCENT=prune_pct)
        pruned_optimizer = torch.optim.Adam(pruned_model.parameters())
        
        # Fine-tune model
        print('-------------- Fine-tuning Pruned Model -------------')
        save_initial = f'model_variants/{task.lower()}_p-{int(prune_pct*100)}_lat-init_f1-init_MTLModel.pth'
        train_mtl_model_individual(num_epochs=num_epochs, model=pruned_model, optimizer=pruned_optimizer,
                              train_loader=train_loader, val_loader=val_loader,
                              age_criterion=age_criterion, age_coeff=1.0, gender_coeff=1.0, ethnicity_coeff=1.0,
                              save=True, save_name=save_initial, isAge=True)

        
        # Test latency and accuracy (F1) and save model variant (and update lookup file)
        [scores, [mean_lat, std_lat]] = get_f1_and_lat(model_path=save_initial,
                                                       eval_dataset=val_dataset,
                                                       eval_dataloader=val_loader,
                                                       tasks=tasks,
                                                       mtl_model=True)
        
        # Save model with score and latency information in the model name
        ager2 = scores['age'][1]
        row = [task.upper(), prune_pct, mean_lat, std_lat, ager2, 0.0, 0.0]
        with open('models/model_variants/model_score_lookup_multitask.tsv', 'a', newline='') as f:
            writer = csv.writer(f, delimiter='\t')
            writer.writerow(row)
            
        new_name = f'model_variants/{task.lower()}_p-{int(prune_pct*100)}_MTLModel.pth'
        torch.save(model, f"models/{new_name}")
        
    else:
        print('Invalid task was specified.')
        
        
    # Delete intermediate model files
    os.remove(f'models/{save_initial}')
    if save_initial != save_no_prune:
        os.remove(f'models/{save_no_prune}')
        
    return scores, mean_lat, std_lat

# %% [markdown]
# #### 0% to 90% Pruning

# %%
task = 'all'
num_epochs = 10
with open('models/model_variants/model_score_lookup_multitask.tsv', 'w', newline='') as f:
    writer = csv.writer(f, delimiter='\t')
    writer.writerow(['Task', 'prune_pct', 'mean_latency', 'std_latency', 'age_r2', 'gender_f1', 'ethnicity_f1'])
            
for i in range(10):
    print(f'--------------------------------- Prune {i*10} % ---------------------------------')
    prune_pct = 1.0*i / 10
    scores, mean_lat, std_lat = pruned_mtl_training(task, prune_pct, num_epochs, train_loader, val_loader, val_dataset)
    print()
# Out:
# --------------------------------- Prune 0 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.11857, train loss: 0.15138
# Epoch 0, age val loss: 0.03198, gender val loss: 0.03448, ethnicity val loss: 0.05211
# Epoch 1, val loss: 0.11857 -> 0.10652, train loss: 0.10865
# Epoch 1, age val loss: 0.02263, gender val loss: 0.03321, ethnicity val loss: 0.05068
# Epoch 2, val loss: 0.10652 -> 0.08065, train loss: 0.09472
# Epoch 2, age val loss: 0.01876, gender val loss: 0.02532, ethnicity val loss: 0.03656
# Epoch 3, val loss: 0.08939, train loss: 0.08537
# Epoch 3, age val loss: 0.02293, gender val loss: 0.02899, ethnicity val loss: 0.03748
# Epoch 4, val loss: 0.08065 -> 0.07744, train loss: 0.07740
# Epoch 4, age val loss: 0.01909, gender val loss: 0.02251, ethnicity val loss: 0.03585
# Epoch 5, val loss: 0.09346, train loss: 0.06696
# Epoch 5, age val loss: 0.01788, gender val loss: 0.04063, ethnicity val loss: 0.03495
# Epoch 6, val loss: 0.08257, train loss: 0.06076
# Epoch 6, age val loss: 0.01656, gender val loss: 0.02687, ethnicity val loss: 0.03914
# Epoch 7, val loss: 0.08543, train loss: 0.05354
# Epoch 7, age val loss: 0.01758, gender val loss: 0.02828, ethnicity val loss: 0.03958
# Epoch 8, val loss: 0.08061, train loss: 0.04713
# Epoch 8, age val loss: 0.01510, gender val loss: 0.03042, ethnicity val loss: 0.03509
# Epoch 9, val loss: 0.08952, train loss: 0.04140
# Epoch 9, age val loss: 0.01649, gender val loss: 0.03407, ethnicity val loss: 0.03896
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.08129, train loss: 0.06913
# Epoch 0, age val loss: 0.01745, gender val loss: 0.02828, ethnicity val loss: 0.03556
# Epoch 1, val loss: 0.08129 -> 0.07957, train loss: 0.06173
# Epoch 1, age val loss: 0.01747, gender val loss: 0.02687, ethnicity val loss: 0.03523
# Epoch 2, val loss: 0.10527, train loss: 0.05454
# Epoch 2, age val loss: 0.02191, gender val loss: 0.04946, ethnicity val loss: 0.03390
# Epoch 3, val loss: 0.09188, train loss: 0.04895
# Epoch 3, age val loss: 0.01591, gender val loss: 0.03303, ethnicity val loss: 0.04294
# Epoch 4, val loss: 0.08438, train loss: 0.04523
# Epoch 4, age val loss: 0.01721, gender val loss: 0.03084, ethnicity val loss: 0.03633
# Epoch 5, val loss: 0.08884, train loss: 0.03908
# Epoch 5, age val loss: 0.02044, gender val loss: 0.03270, ethnicity val loss: 0.03570
# Epoch 6, val loss: 0.11530, train loss: 0.03320
# Epoch 6, age val loss: 0.01572, gender val loss: 0.05646, ethnicity val loss: 0.04312
# Epoch 7, val loss: 0.09376, train loss: 0.03176
# Epoch 7, age val loss: 0.01621, gender val loss: 0.03801, ethnicity val loss: 0.03953
# Epoch 8, val loss: 0.09326, train loss: 0.02996
# Epoch 8, age val loss: 0.02559, gender val loss: 0.02749, ethnicity val loss: 0.04018
# Epoch 9, val loss: 0.10374, train loss: 0.02764
# Epoch 9, age val loss: 0.01596, gender val loss: 0.04050, ethnicity val loss: 0.04728
#
# --------------------------------- Prune 10 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.14068, train loss: 0.15454
# Epoch 0, age val loss: 0.04795, gender val loss: 0.03575, ethnicity val loss: 0.05698
# Epoch 1, val loss: 0.14068 -> 0.10342, train loss: 0.11014
# Epoch 1, age val loss: 0.02481, gender val loss: 0.03068, ethnicity val loss: 0.04793
# Epoch 2, val loss: 0.10342 -> 0.09137, train loss: 0.09596
# Epoch 2, age val loss: 0.01797, gender val loss: 0.03440, ethnicity val loss: 0.03900
# Epoch 3, val loss: 0.09137 -> 0.07842, train loss: 0.08556
# Epoch 3, age val loss: 0.01823, gender val loss: 0.02392, ethnicity val loss: 0.03627
# Epoch 4, val loss: 0.08033, train loss: 0.07645
# Epoch 4, age val loss: 0.01840, gender val loss: 0.02465, ethnicity val loss: 0.03728
# Epoch 5, val loss: 0.07842 -> 0.07830, train loss: 0.06777
# Epoch 5, age val loss: 0.01787, gender val loss: 0.02454, ethnicity val loss: 0.03588
# Epoch 6, val loss: 0.08679, train loss: 0.06102
# Epoch 6, age val loss: 0.01782, gender val loss: 0.02324, ethnicity val loss: 0.04574
# Epoch 7, val loss: 0.08770, train loss: 0.05362
# Epoch 7, age val loss: 0.01743, gender val loss: 0.03288, ethnicity val loss: 0.03739
# Epoch 8, val loss: 0.08224, train loss: 0.04999
# Epoch 8, age val loss: 0.01692, gender val loss: 0.02664, ethnicity val loss: 0.03868
# Epoch 9, val loss: 0.07830 -> 0.07793, train loss: 0.04264
# Epoch 9, age val loss: 0.01578, gender val loss: 0.02561, ethnicity val loss: 0.03653
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.10255, train loss: 0.04354
# Epoch 0, age val loss: 0.01912, gender val loss: 0.03407, ethnicity val loss: 0.04937
# Epoch 1, val loss: 0.10634, train loss: 0.03791
# Epoch 1, age val loss: 0.01769, gender val loss: 0.03797, ethnicity val loss: 0.05068
# Epoch 2, val loss: 0.10255 -> 0.09390, train loss: 0.03490
# Epoch 2, age val loss: 0.01677, gender val loss: 0.03751, ethnicity val loss: 0.03962
# Epoch 3, val loss: 0.11599, train loss: 0.03323
# Epoch 3, age val loss: 0.01848, gender val loss: 0.04489, ethnicity val loss: 0.05262
# Epoch 4, val loss: 0.12392, train loss: 0.03044
# Epoch 4, age val loss: 0.01735, gender val loss: 0.05429, ethnicity val loss: 0.05229
# Epoch 5, val loss: 0.10705, train loss: 0.02928
# Epoch 5, age val loss: 0.01614, gender val loss: 0.04281, ethnicity val loss: 0.04810
# Epoch 6, val loss: 0.11669, train loss: 0.02699
# Epoch 6, age val loss: 0.02303, gender val loss: 0.04250, ethnicity val loss: 0.05117
# Epoch 7, val loss: 0.12356, train loss: 0.02554
# Epoch 7, age val loss: 0.01883, gender val loss: 0.05093, ethnicity val loss: 0.05381
# Epoch 8, val loss: 0.13311, train loss: 0.02327
# Epoch 8, age val loss: 0.02593, gender val loss: 0.05305, ethnicity val loss: 0.05412
# Epoch 9, val loss: 0.10236, train loss: 0.02180
# Epoch 9, age val loss: 0.01658, gender val loss: 0.03247, ethnicity val loss: 0.05331
#
# --------------------------------- Prune 20 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.11727, train loss: 0.15698
# Epoch 0, age val loss: 0.03145, gender val loss: 0.03817, ethnicity val loss: 0.04765
# Epoch 1, val loss: 0.11727 -> 0.09685, train loss: 0.11336
# Epoch 1, age val loss: 0.02665, gender val loss: 0.02526, ethnicity val loss: 0.04493
# Epoch 2, val loss: 0.09685 -> 0.09494, train loss: 0.09551
# Epoch 2, age val loss: 0.02180, gender val loss: 0.03137, ethnicity val loss: 0.04177
# Epoch 3, val loss: 0.09494 -> 0.09489, train loss: 0.08497
# Epoch 3, age val loss: 0.01868, gender val loss: 0.03959, ethnicity val loss: 0.03662
# Epoch 4, val loss: 0.09489 -> 0.07436, train loss: 0.07640
# Epoch 4, age val loss: 0.01620, gender val loss: 0.02460, ethnicity val loss: 0.03356
# Epoch 5, val loss: 0.07500, train loss: 0.06764
# Epoch 5, age val loss: 0.01613, gender val loss: 0.02323, ethnicity val loss: 0.03565
# Epoch 6, val loss: 0.07829, train loss: 0.06154
# Epoch 6, age val loss: 0.01624, gender val loss: 0.02630, ethnicity val loss: 0.03574
# Epoch 7, val loss: 0.09336, train loss: 0.05319
# Epoch 7, age val loss: 0.01930, gender val loss: 0.02956, ethnicity val loss: 0.04449
# Epoch 8, val loss: 0.08961, train loss: 0.04708
# Epoch 8, age val loss: 0.01876, gender val loss: 0.02943, ethnicity val loss: 0.04142
# Epoch 9, val loss: 0.09812, train loss: 0.04184
# Epoch 9, age val loss: 0.01789, gender val loss: 0.04127, ethnicity val loss: 0.03896
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.08168, train loss: 0.08095
# Epoch 0, age val loss: 0.02129, gender val loss: 0.02444, ethnicity val loss: 0.03594
# Epoch 1, val loss: 0.08168 -> 0.07944, train loss: 0.06878
# Epoch 1, age val loss: 0.01630, gender val loss: 0.02753, ethnicity val loss: 0.03562
# Epoch 2, val loss: 0.07944 -> 0.07533, train loss: 0.06013
# Epoch 2, age val loss: 0.01748, gender val loss: 0.02486, ethnicity val loss: 0.03299
# Epoch 3, val loss: 0.07823, train loss: 0.05363
# Epoch 3, age val loss: 0.01714, gender val loss: 0.02562, ethnicity val loss: 0.03547
# Epoch 4, val loss: 0.08690, train loss: 0.04762
# Epoch 4, age val loss: 0.01685, gender val loss: 0.03091, ethnicity val loss: 0.03914
# Epoch 5, val loss: 0.09574, train loss: 0.04187
# Epoch 5, age val loss: 0.01796, gender val loss: 0.03410, ethnicity val loss: 0.04368
# Epoch 6, val loss: 0.10620, train loss: 0.03908
# Epoch 6, age val loss: 0.01636, gender val loss: 0.04854, ethnicity val loss: 0.04130
# Epoch 7, val loss: 0.08894, train loss: 0.03491
# Epoch 7, age val loss: 0.01625, gender val loss: 0.03241, ethnicity val loss: 0.04028
# Epoch 8, val loss: 0.09958, train loss: 0.03206
# Epoch 8, age val loss: 0.02010, gender val loss: 0.03690, ethnicity val loss: 0.04258
# Epoch 9, val loss: 0.11179, train loss: 0.02956
# Epoch 9, age val loss: 0.01721, gender val loss: 0.04452, ethnicity val loss: 0.05006
#
# --------------------------------- Prune 40 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.11134, train loss: 0.15509
# Epoch 0, age val loss: 0.02212, gender val loss: 0.03606, ethnicity val loss: 0.05316
# Epoch 1, val loss: 0.11134 -> 0.09416, train loss: 0.10953
# Epoch 1, age val loss: 0.02172, gender val loss: 0.02852, ethnicity val loss: 0.04392
# Epoch 2, val loss: 0.09416 -> 0.08703, train loss: 0.09413
# Epoch 2, age val loss: 0.02180, gender val loss: 0.02463, ethnicity val loss: 0.04060
# Epoch 3, val loss: 0.08703 -> 0.08630, train loss: 0.08452
# Epoch 3, age val loss: 0.01831, gender val loss: 0.02936, ethnicity val loss: 0.03863
# Epoch 4, val loss: 0.08630 -> 0.08212, train loss: 0.07568
# Epoch 4, age val loss: 0.01862, gender val loss: 0.02856, ethnicity val loss: 0.03495
# Epoch 5, val loss: 0.08212 -> 0.07514, train loss: 0.06806
# Epoch 5, age val loss: 0.01797, gender val loss: 0.02308, ethnicity val loss: 0.03410
# Epoch 6, val loss: 0.07854, train loss: 0.05873
# Epoch 6, age val loss: 0.01702, gender val loss: 0.02705, ethnicity val loss: 0.03447
# Epoch 7, val loss: 0.09985, train loss: 0.05216
# Epoch 7, age val loss: 0.02845, gender val loss: 0.02833, ethnicity val loss: 0.04307
# Epoch 8, val loss: 0.09039, train loss: 0.04784
# Epoch 8, age val loss: 0.02004, gender val loss: 0.03324, ethnicity val loss: 0.03711
# Epoch 9, val loss: 0.09916, train loss: 0.04127
# Epoch 9, age val loss: 0.01538, gender val loss: 0.04035, ethnicity val loss: 0.04343
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.10123, train loss: 0.14678
# Epoch 0, age val loss: 0.02300, gender val loss: 0.03423, ethnicity val loss: 0.04400
# Epoch 1, val loss: 0.10123 -> 0.09350, train loss: 0.09618
# Epoch 1, age val loss: 0.02428, gender val loss: 0.02990, ethnicity val loss: 0.03932
# Epoch 2, val loss: 0.09350 -> 0.09153, train loss: 0.08101
# Epoch 2, age val loss: 0.01934, gender val loss: 0.02868, ethnicity val loss: 0.04351
# Epoch 3, val loss: 0.09153 -> 0.08648, train loss: 0.07145
# Epoch 3, age val loss: 0.02036, gender val loss: 0.02852, ethnicity val loss: 0.03760
# Epoch 4, val loss: 0.08954, train loss: 0.06376
# Epoch 4, age val loss: 0.02264, gender val loss: 0.02923, ethnicity val loss: 0.03766
# Epoch 5, val loss: 0.09546, train loss: 0.05744
# Epoch 5, age val loss: 0.02004, gender val loss: 0.03401, ethnicity val loss: 0.04141
# Epoch 6, val loss: 0.08959, train loss: 0.05303
# Epoch 6, age val loss: 0.01844, gender val loss: 0.03175, ethnicity val loss: 0.03939
# Epoch 7, val loss: 0.09049, train loss: 0.04715
# Epoch 7, age val loss: 0.02058, gender val loss: 0.03104, ethnicity val loss: 0.03886
# Epoch 8, val loss: 0.09531, train loss: 0.04467
# Epoch 8, age val loss: 0.01997, gender val loss: 0.03379, ethnicity val loss: 0.04154
# Epoch 9, val loss: 0.09604, train loss: 0.04070
# Epoch 9, age val loss: 0.01909, gender val loss: 0.03276, ethnicity val loss: 0.04419
#
# --------------------------------- Prune 60 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.10995, train loss: 0.15705
# Epoch 0, age val loss: 0.03324, gender val loss: 0.02956, ethnicity val loss: 0.04715
# Epoch 1, val loss: 0.11381, train loss: 0.10948
# Epoch 1, age val loss: 0.02278, gender val loss: 0.04897, ethnicity val loss: 0.04205
# Epoch 2, val loss: 0.10995 -> 0.08732, train loss: 0.09586
# Epoch 2, age val loss: 0.02054, gender val loss: 0.02928, ethnicity val loss: 0.03750
# Epoch 3, val loss: 0.10119, train loss: 0.08541
# Epoch 3, age val loss: 0.02436, gender val loss: 0.02651, ethnicity val loss: 0.05032
# Epoch 4, val loss: 0.08732 -> 0.08560, train loss: 0.07716
# Epoch 4, age val loss: 0.01700, gender val loss: 0.03136, ethnicity val loss: 0.03724
# Epoch 5, val loss: 0.08560 -> 0.07761, train loss: 0.06666
# Epoch 5, age val loss: 0.01705, gender val loss: 0.02696, ethnicity val loss: 0.03360
# Epoch 6, val loss: 0.09103, train loss: 0.06019
# Epoch 6, age val loss: 0.02437, gender val loss: 0.02788, ethnicity val loss: 0.03878
# Epoch 7, val loss: 0.07761 -> 0.07409, train loss: 0.05340
# Epoch 7, age val loss: 0.01775, gender val loss: 0.02320, ethnicity val loss: 0.03314
# Epoch 8, val loss: 0.08384, train loss: 0.04803
# Epoch 8, age val loss: 0.01937, gender val loss: 0.02643, ethnicity val loss: 0.03803
# Epoch 9, val loss: 0.09645, train loss: 0.04099
# Epoch 9, age val loss: 0.01694, gender val loss: 0.03802, ethnicity val loss: 0.04148
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.21647, train loss: 0.24011
# Epoch 0, age val loss: 0.08101, gender val loss: 0.05559, ethnicity val loss: 0.07988
# Epoch 1, val loss: 0.21647 -> 0.17415, train loss: 0.17871
# Epoch 1, age val loss: 0.05215, gender val loss: 0.04971, ethnicity val loss: 0.07229
# Epoch 2, val loss: 0.17415 -> 0.14186, train loss: 0.15802
# Epoch 2, age val loss: 0.03645, gender val loss: 0.04070, ethnicity val loss: 0.06471
# Epoch 3, val loss: 0.14186 -> 0.13765, train loss: 0.14756
# Epoch 3, age val loss: 0.03478, gender val loss: 0.03921, ethnicity val loss: 0.06365
# Epoch 4, val loss: 0.13947, train loss: 0.13988
# Epoch 4, age val loss: 0.03857, gender val loss: 0.03785, ethnicity val loss: 0.06305
# Epoch 5, val loss: 0.13765 -> 0.12945, train loss: 0.13387
# Epoch 5, age val loss: 0.03091, gender val loss: 0.04053, ethnicity val loss: 0.05800
# Epoch 6, val loss: 0.16039, train loss: 0.12809
# Epoch 6, age val loss: 0.06348, gender val loss: 0.03738, ethnicity val loss: 0.05953
# Epoch 7, val loss: 0.12945 -> 0.12921, train loss: 0.12558
# Epoch 7, age val loss: 0.03069, gender val loss: 0.04070, ethnicity val loss: 0.05783
# Epoch 8, val loss: 0.12921 -> 0.12754, train loss: 0.12064
# Epoch 8, age val loss: 0.03188, gender val loss: 0.04154, ethnicity val loss: 0.05412
# Epoch 9, val loss: 0.12754 -> 0.12257, train loss: 0.11726
# Epoch 9, age val loss: 0.02845, gender val loss: 0.03817, ethnicity val loss: 0.05596
#
# --------------------------------- Prune 90 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.09945, train loss: 0.15565
# Epoch 0, age val loss: 0.02888, gender val loss: 0.03036, ethnicity val loss: 0.04021
# Epoch 1, val loss: 0.09945 -> 0.09394, train loss: 0.11027
# Epoch 1, age val loss: 0.02065, gender val loss: 0.02791, ethnicity val loss: 0.04538
# Epoch 2, val loss: 0.09394 -> 0.08587, train loss: 0.09492
# Epoch 2, age val loss: 0.01927, gender val loss: 0.02784, ethnicity val loss: 0.03876
# Epoch 3, val loss: 0.08587 -> 0.08215, train loss: 0.08461
# Epoch 3, age val loss: 0.01955, gender val loss: 0.02763, ethnicity val loss: 0.03498
# Epoch 4, val loss: 0.09863, train loss: 0.07495
# Epoch 4, age val loss: 0.01915, gender val loss: 0.04048, ethnicity val loss: 0.03901
# Epoch 5, val loss: 0.08215 -> 0.07882, train loss: 0.06944
# Epoch 5, age val loss: 0.01657, gender val loss: 0.02569, ethnicity val loss: 0.03657
# Epoch 6, val loss: 0.08110, train loss: 0.06058
# Epoch 6, age val loss: 0.01642, gender val loss: 0.02880, ethnicity val loss: 0.03589
# Epoch 7, val loss: 0.08964, train loss: 0.05278
# Epoch 7, age val loss: 0.02053, gender val loss: 0.02966, ethnicity val loss: 0.03945
# Epoch 8, val loss: 0.08496, train loss: 0.04656
# Epoch 8, age val loss: 0.01665, gender val loss: 0.02966, ethnicity val loss: 0.03866
# Epoch 9, val loss: 0.09428, train loss: 0.04163
# Epoch 9, age val loss: 0.01613, gender val loss: 0.04171, ethnicity val loss: 0.03645
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.26434, train loss: 0.28964
# Epoch 0, age val loss: 0.08954, gender val loss: 0.08593, ethnicity val loss: 0.08887
# Epoch 1, val loss: 0.26434 -> 0.24273, train loss: 0.24950
# Epoch 1, age val loss: 0.07870, gender val loss: 0.07750, ethnicity val loss: 0.08653
# Epoch 2, val loss: 0.25926, train loss: 0.22956
# Epoch 2, age val loss: 0.09066, gender val loss: 0.08142, ethnicity val loss: 0.08718
# Epoch 3, val loss: 0.24273 -> 0.21201, train loss: 0.21858
# Epoch 3, age val loss: 0.05848, gender val loss: 0.06721, ethnicity val loss: 0.08632
# Epoch 4, val loss: 0.21201 -> 0.20928, train loss: 0.21383
# Epoch 4, age val loss: 0.05909, gender val loss: 0.06351, ethnicity val loss: 0.08669
# Epoch 5, val loss: 0.21364, train loss: 0.21081
# Epoch 5, age val loss: 0.05974, gender val loss: 0.06710, ethnicity val loss: 0.08680
# Epoch 6, val loss: 0.20928 -> 0.20156, train loss: 0.20774
# Epoch 6, age val loss: 0.05537, gender val loss: 0.05943, ethnicity val loss: 0.08677
# Epoch 7, val loss: 0.21619, train loss: 0.20661
# Epoch 7, age val loss: 0.05924, gender val loss: 0.06959, ethnicity val loss: 0.08736
# Epoch 8, val loss: 0.20156 -> 0.19902, train loss: 0.20484
# Epoch 8, age val loss: 0.05325, gender val loss: 0.05976, ethnicity val loss: 0.08601
# Epoch 9, val loss: 0.20650, train loss: 0.20294
# Epoch 9, age val loss: 0.06048, gender val loss: 0.05889, ethnicity val loss: 0.08712

# %% [markdown]
# Notes: pruning the linear task-specific layers was sometimes causing an index-out-of-bounds error, which I think is due to it pruning off the final layer. As a fix, trying ignoring the last layer when pruning the linear layers. Note: once I edited the linear layer pruning to not prune the last layer, this problem was resolved.
#
# However, pruning the linear layer caused more drastic performance decreases, so changed it to only prune the convolutional layers.
#
# Note: pruning causes poor performance. Things to try: reset optimizer before pruning. This worked
#
# Notes about this notebook. The MTL notebook generates models by first training the multitask model, pruning it, and finetuning it either for MTL or for specific tasks. The other notebook, SingleTask, does not use the MTL model or objtective at all.

# %% [markdown]
# #### Age

# %%
task = 'age'
num_epochs = 10
            
for i in range(10):
    print(f'--------------------------------- Prune {i*10} % ---------------------------------')
    prune_pct = 1.0*i / 10
    scores, mean_lat, std_lat = pruned_mtl_training(task, prune_pct, num_epochs, train_loader, val_loader, val_dataset)
    print()
# Out:
# --------------------------------- Prune 0 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 19.42481, train loss: 15.50330
# Epoch 1, val loss: 19.42481 -> 10.23221, train loss: 10.69231
# Epoch 2, val loss: 10.23221 -> 8.33375, train loss: 9.64313
# Epoch 3, val loss: 8.33375 -> 7.56699, train loss: 8.84791
# Epoch 4, val loss: 7.56699 -> 7.32463, train loss: 8.05564
# Epoch 5, val loss: 7.32463 -> 6.97332, train loss: 7.86455
# Epoch 6, val loss: 7.27164, train loss: 7.14642
# Epoch 7, val loss: 7.04004, train loss: 6.96903
# Epoch 8, val loss: 7.05859, train loss: 6.61797
# Epoch 9, val loss: 7.08121, train loss: 6.58568
#
# --------------------------------- Prune 90 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.10733, train loss: 0.15397
# Epoch 0, age val loss: 0.02270, gender val loss: 0.03520, ethnicity val loss: 0.04943
# Epoch 1, val loss: 0.10752, train loss: 0.10889
# Epoch 1, age val loss: 0.03385, gender val loss: 0.02766, ethnicity val loss: 0.04601
# Epoch 2, val loss: 0.11226, train loss: 0.09314
# Epoch 2, age val loss: 0.02960, gender val loss: 0.04317, ethnicity val loss: 0.03949
# Epoch 3, val loss: 0.10733 -> 0.10231, train loss: 0.08416
# Epoch 3, age val loss: 0.02730, gender val loss: 0.02802, ethnicity val loss: 0.04699
# Epoch 4, val loss: 0.10231 -> 0.07921, train loss: 0.07619
# Epoch 4, age val loss: 0.01844, gender val loss: 0.02483, ethnicity val loss: 0.03593
# Epoch 5, val loss: 0.08351, train loss: 0.06657
# Epoch 5, age val loss: 0.01933, gender val loss: 0.02800, ethnicity val loss: 0.03618
# Epoch 6, val loss: 0.07921 -> 0.07792, train loss: 0.05917
# Epoch 6, age val loss: 0.01578, gender val loss: 0.02777, ethnicity val loss: 0.03437
# Epoch 7, val loss: 0.11007, train loss: 0.05252
# Epoch 7, age val loss: 0.03687, gender val loss: 0.03282, ethnicity val loss: 0.04038
# Epoch 8, val loss: 0.09574, train loss: 0.04821
# Epoch 8, age val loss: 0.01612, gender val loss: 0.04033, ethnicity val loss: 0.03929
# Epoch 9, val loss: 0.09089, train loss: 0.04242
# Epoch 9, age val loss: 0.01520, gender val loss: 0.03569, ethnicity val loss: 0.04000
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 18.57108, train loss: 24.10669
# Epoch 1, val loss: 18.57108 -> 15.78064, train loss: 17.35468
# Epoch 2, val loss: 15.78064 -> 14.06207, train loss: 15.00175
# Epoch 3, val loss: 14.06207 -> 11.87621, train loss: 13.68598
# Epoch 4, val loss: 11.87621 -> 11.51956, train loss: 12.99270
# Epoch 5, val loss: 19.76168, train loss: 12.54158
# Epoch 6, val loss: 12.18277, train loss: 12.13174
# Epoch 7, val loss: 11.51956 -> 10.77028, train loss: 11.69349
# Epoch 8, val loss: 10.77028 -> 10.04791, train loss: 11.49493
# Epoch 9, val loss: 10.39168, train loss: 11.20150

# %% [markdown]
# #### Gender

# %%
task = 'gender'
num_epochs = 10

for i in range(10):
    print(f'--------------------------------- Prune {i*10} % ---------------------------------')
    prune_pct = 1.0*i / 10
    scores, mean_lat, std_lat = pruned_mtl_training(task, prune_pct, num_epochs, train_loader, val_loader, val_dataset)
    print()
# Out:
# --------------------------------- Prune 0 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.16809, train loss: 0.15701
# Epoch 0, age val loss: 0.06767, gender val loss: 0.03984, ethnicity val loss: 0.06058
# Epoch 1, val loss: 0.16809 -> 0.10571, train loss: 0.11271
# Epoch 1, age val loss: 0.02388, gender val loss: 0.02941, ethnicity val loss: 0.05243
# Epoch 2, val loss: 0.10571 -> 0.08599, train loss: 0.09637
# Epoch 2, age val loss: 0.02035, gender val loss: 0.02666, ethnicity val loss: 0.03899
# Epoch 3, val loss: 0.09771, train loss: 0.08618
# Epoch 3, age val loss: 0.02326, gender val loss: 0.02655, ethnicity val loss: 0.04791
# Epoch 4, val loss: 0.09429, train loss: 0.07688
# Epoch 4, age val loss: 0.02480, gender val loss: 0.02427, ethnicity val loss: 0.04522
# Epoch 5, val loss: 0.08599 -> 0.08455, train loss: 0.06948
# Epoch 5, age val loss: 0.01644, gender val loss: 0.03134, ethnicity val loss: 0.03678
# Epoch 6, val loss: 0.08455 -> 0.08092, train loss: 0.06081
# Epoch 6, age val loss: 0.01679, gender val loss: 0.02281, ethnicity val loss: 0.04133
# Epoch 7, val loss: 0.08265, train loss: 0.05537
# Epoch 7, age val loss: 0.01528, gender val loss: 0.02813, ethnicity val loss: 0.03924
# Epoch 8, val loss: 0.08960, train loss: 0.04801
# Epoch 8, age val loss: 0.01681, gender val loss: 0.03576, ethnicity val loss: 0.03703
# Epoch 9, val loss: 0.10368, train loss: 0.04459
# Epoch 9, age val loss: 0.01613, gender val loss: 0.04894, ethnicity val loss: 0.03861
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.01405, train loss: 0.00991
# Epoch 1, val loss: 0.01466, train loss: 0.00818
# Epoch 2, val loss: 0.01457, train loss: 0.00600
# Epoch 3, val loss: 0.01405 -> 0.01371, train loss: 0.00733
# Epoch 4, val loss: 0.01744, train loss: 0.00520
# Epoch 5, val loss: 0.01838, train loss: 0.00481
# Epoch 6, val loss: 0.01536, train loss: 0.00552
# Epoch 7, val loss: 0.02064, train loss: 0.00314
# Epoch 8, val loss: 0.02955, train loss: 0.00366
# Epoch 9, val loss: 0.02409, train loss: 0.00264
#
# --------------------------------- Prune 10 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.13966, train loss: 0.15606
# Epoch 0, age val loss: 0.03947, gender val loss: 0.03875, ethnicity val loss: 0.06143
# Epoch 1, val loss: 0.13966 -> 0.08679, train loss: 0.11005
# Epoch 1, age val loss: 0.02288, gender val loss: 0.02564, ethnicity val loss: 0.03827
# Epoch 2, val loss: 0.08679 -> 0.08404, train loss: 0.09506
# Epoch 2, age val loss: 0.02094, gender val loss: 0.02523, ethnicity val loss: 0.03787
# Epoch 3, val loss: 0.08404 -> 0.08146, train loss: 0.08619
# Epoch 3, age val loss: 0.01697, gender val loss: 0.02668, ethnicity val loss: 0.03781
# Epoch 4, val loss: 0.08362, train loss: 0.07729
# Epoch 4, age val loss: 0.01842, gender val loss: 0.02671, ethnicity val loss: 0.03849
# Epoch 5, val loss: 0.08366, train loss: 0.06916
% ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.10879, train loss: 0.15286
# Epoch 0, age val loss: 0.02902, gender val loss: 0.03356, ethnicity val loss: 0.04622
# Epoch 1, val loss: 0.10879 -> 0.09478, train loss: 0.11049
# Epoch 1, age val loss: 0.02159, gender val loss: 0.03378, ethnicity val loss: 0.03940
# Epoch 2, val loss: 0.09478 -> 0.08809, train loss: 0.09458
# Epoch 2, age val loss: 0.02066, gender val loss: 0.02784, ethnicity val loss: 0.03959
# Epoch 3, val loss: 0.08809 -> 0.07871, train loss: 0.08308
# Epoch 3, age val loss: 0.01633, gender val loss: 0.02488, ethnicity val loss: 0.03750
# Epoch 4, val loss: 0.09260, train loss: 0.07553
# Epoch 4, age val loss: 0.02924, gender val loss: 0.02816, ethnicity val loss: 0.03520
# Epoch 5, val loss: 0.09100, train loss: 0.06804
# Epoch 5, age val loss: 0.01802, gender val loss: 0.03916, ethnicity val loss: 0.03381
# Epoch 6, val loss: 0.07871 -> 0.07789, train loss: 0.05990
# Epoch 6, age val loss: 0.01590, gender val loss: 0.02286, ethnicity val loss: 0.03914
# Epoch 7, val loss: 0.08104, train loss: 0.05401
# Epoch 7, age val loss: 0.01847, gender val loss: 0.02469, ethnicity val loss: 0.03789
# Epoch 8, val loss: 0.08576, train loss: 0.04725
# Epoch 8, age val loss: 0.01586, gender val loss: 0.03397, ethnicity val loss: 0.03593
# Epoch 9, val loss: 0.10292, train loss: 0.04185
# Epoch 9, age val loss: 0.01674, gender val loss: 0.04242, ethnicity val loss: 0.04377
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.01317, train loss: 0.01245
# Epoch 1, val loss: 0.01900, train loss: 0.00919
# Epoch 2, val loss: 0.01644, train loss: 0.00780
# Epoch 3, val loss: 0.01875, train loss: 0.00649
# Epoch 4, val loss: 0.01659, train loss: 0.00531
# Epoch 5, val loss: 0.01780, train loss: 0.00491
# Epoch 6, val loss: 0.01774, train loss: 0.00428
# Epoch 7, val loss: 0.02364, train loss: 0.00369
# Epoch 8, val loss: 0.01909, train loss: 0.00370
# Epoch 9, val loss: 0.02152, train loss: 0.00349
#
# --------------------------------- Prune 40 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.11467, train loss: 0.15510
# Epoch 0, age val loss: 0.03341, gender val loss: 0.03067, ethnicity val loss: 0.05058
# Epoch 1, val loss: 0.11467 -> 0.09981, train loss: 0.10919
# Epoch 1, age val loss: 0.02618, gender val loss: 0.02697, ethnicity val loss: 0.04667
# Epoch 2, val loss: 0.09981 -> 0.08642, train loss: 0.09666
# Epoch 2, age val loss: 0.01979, gender val loss: 0.02685, ethnicity val loss: 0.03978
# Epoch 3, val loss: 0.10317, train loss: 0.08515
# Epoch 3, age val loss: 0.03079, gender val loss: 0.02996, ethnicity val loss: 0.04242
# Epoch 4, val loss: 0.08642 -> 0.08416, train loss: 0.07483
# Epoch 4, age val loss: 0.01970, gender val loss: 0.02700, ethnicity val loss: 0.03746
# Epoch 5, val loss: 0.08416 -> 0.08195, train loss: 0.06872
# Epoch 5, age val loss: 0.01835, gender val loss: 0.02637, ethnicity val loss: 0.03723
# Epoch 6, val loss: 0.08195 -> 0.08026, train loss: 0.06132
# Epoch 6, age val loss: 0.01717, gender val loss: 0.02663, ethnicity val loss: 0.03645
# Epoch 7, val loss: 0.08209, train loss: 0.05289
# Epoch 7, age val loss: 0.01832, gender val loss: 0.02634, ethnicity val loss: 0.03743
# Epoch 8, val loss: 0.09414, train loss: 0.04759
# Epoch 8, age val loss: 0.01667, gender val loss: 0.04053, ethnicity val loss: 0.03694
# Epoch 9, val loss: 0.09542, train loss: 0.04249
# Epoch 9, age val loss: 0.01688, gender val loss: 0.03353, ethnicity val loss: 0.04501
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.01423, train loss: 0.01635
# Epoch 1, val loss: 0.01423 -> 0.01386, train loss: 0.01192
# Epoch 2, val loss: 0.01457, train loss: 0.00978
# Epoch 3, val loss: 0.01453, train loss: 0.00782
# Epoch 4, val loss: 0.01514, train loss: 0.00711
# Epoch 5, val loss: 0.01842, train loss: 0.00580
# Epoch 6, val loss: 0.01801, train loss: 0.00535
# Epoch 7, val loss: 0.01908, train loss: 0.00404
# Epoch 8, val loss: 0.02228, train loss: 0.00359
# Epoch 9, val loss: 0.02942, train loss: 0.00308
#
# --------------------------------- Prune 50 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.11305, train loss: 0.15602
# Epoch 0, age val loss: 0.02799, gender val loss: 0.03668, ethnicity val loss: 0.04837
# Epoch 1, val loss: 0.11305 -> 0.09530, train loss: 0.10941
# Epoch 1, age val loss: 0.02209, gender val loss: 0.02836, ethnicity val loss: 0.04484
# Epoch 2, val loss: 0.09530 -> 0.09034, train loss: 0.09612
# Epoch 2, age val loss: 0.01796, gender val loss: 0.02569, ethnicity val loss: 0.04669
# Epoch 3, val loss: 0.10432, train loss: 0.08463
# Epoch 3, age val loss: 0.02402, gender val loss: 0.04119, ethnicity val loss: 0.03911
# Epoch 4, val loss: 0.09034 -> 0.08324, train loss: 0.07734
# Epoch 4, age val loss: 0.02348, gender val loss: 0.02427, ethnicity val loss: 0.03549
# Epoch 5, val loss: 0.08324 -> 0.08160, train loss: 0.06764
# Epoch 5, age val loss: 0.01813, gender val loss: 0.02614, ethnicity val loss: 0.03733
# Epoch 6, val loss: 0.09107, train loss: 0.06083
# Epoch 6, age val loss: 0.02373, gender val loss: 0.02918, ethnicity val loss: 0.03816
# Epoch 7, val loss: 0.08160 -> 0.08130, train loss: 0.05339
# Epoch 7, age val loss: 0.01735, gender val loss: 0.02675, ethnicity val loss: 0.03721
# Epoch 8, val loss: 0.08130 -> 0.08019, train loss: 0.04794
# Epoch 8, age val loss: 0.01657, gender val loss: 0.02818, ethnicity val loss: 0.03543
# Epoch 9, val loss: 0.09734, train loss: 0.04231
# Epoch 9, age val loss: 0.02483, gender val loss: 0.03654, ethnicity val loss: 0.03597
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.01677, train loss: 0.02441
# Epoch 1, val loss: 0.01677 -> 0.01430, train loss: 0.01588
# Epoch 2, val loss: 0.01430 -> 0.01396, train loss: 0.01295
# Epoch 3, val loss: 0.01431, train loss: 0.01105
# Epoch 4, val loss: 0.01569, train loss: 0.00967
# Epoch 5, val loss: 0.01510, train loss: 0.00815
# Epoch 6, val loss: 0.01813, train loss: 0.00691
# Epoch 7, val loss: 0.01712, train loss: 0.00573
# Epoch 8, val loss: 0.02030, train loss: 0.00484
# Epoch 9, val loss: 0.02346, train loss: 0.00451
#
# --------------------------------- Prune 60 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.10868, train loss: 0.15490
# Epoch 0, age val loss: 0.02393, gender val loss: 0.03840, ethnicity val loss: 0.04636
# Epoch 1, val loss: 0.10868 -> 0.09720, train loss: 0.11030
# Epoch 1, age val loss: 0.02629, gender val loss: 0.03119, ethnicity val loss: 0.03971
# Epoch 2, val loss: 0.09720 -> 0.09358, train loss: 0.09485
# Epoch 2, age val loss: 0.02705, gender val loss: 0.02865, ethnicity val loss: 0.03788
# Epoch 3, val loss: 0.09514, train loss: 0.08438
# Epoch 3, age val loss: 0.02556, gender val loss: 0.02631, ethnicity val loss: 0.04327
# Epoch 4, val loss: 0.09358 -> 0.07831, train loss: 0.07512
# Epoch 4, age val loss: 0.01877, gender val loss: 0.02415, ethnicity val loss: 0.03539
# Epoch 5, val loss: 0.08204, train loss: 0.06812
# Epoch 5, age val loss: 0.02293, gender val loss: 0.02503, ethnicity val loss: 0.03408
# Epoch 6, val loss: 0.09646, train loss: 0.06014
# Epoch 6, age val loss: 0.01896, gender val loss: 0.04266, ethnicity val loss: 0.03484
# Epoch 7, val loss: 0.08768, train loss: 0.05348
# Epoch 7, age val loss: 0.01613, gender val loss: 0.02988, ethnicity val loss: 0.04167
# Epoch 8, val loss: 0.08323, train loss: 0.04807
# Epoch 8, age val loss: 0.01720, gender val loss: 0.02555, ethnicity val loss: 0.04048
# Epoch 9, val loss: 0.09472, train loss: 0.04251
# Epoch 9, age val loss: 0.01721, gender val loss: 0.02574, ethnicity val loss: 0.05176
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.02099, train loss: 0.02902
# Epoch 1, val loss: 0.02330, train loss: 0.01984
# Epoch 2, val loss: 0.02099 -> 0.01641, train loss: 0.01715
# Epoch 3, val loss: 0.01641 -> 0.01573, train loss: 0.01470
# Epoch 4, val loss: 0.01636, train loss: 0.01331
# Epoch 5, val loss: 0.01678, train loss: 0.01194
# Epoch 6, val loss: 0.01681, train loss: 0.01055
# Epoch 7, val loss: 0.01949, train loss: 0.00953
# Epoch 8, val loss: 0.01752, train loss: 0.00899
# Epoch 9, val loss: 0.01756, train loss: 0.00751
#
# --------------------------------- Prune 70 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.11556, train loss: 0.15554
# Epoch 0, age val loss: 0.02519, gender val loss: 0.03988, ethnicity val loss: 0.05050
# Epoch 1, val loss: 0.11556 -> 0.10318, train loss: 0.11103
# Epoch 1, age val loss: 0.02767, gender val loss: 0.03290, ethnicity val loss: 0.04262
# Epoch 2, val loss: 0.10318 -> 0.09260, train loss: 0.09666
# Epoch 2, age val loss: 0.02451, gender val loss: 0.02578, ethnicity val loss: 0.04231
# Epoch 3, val loss: 0.09260 -> 0.08733, train loss: 0.08366
# Epoch 3, age val loss: 0.02043, gender val loss: 0.02708, ethnicity val loss: 0.03983
# Epoch 4, val loss: 0.08733 -> 0.08285, train loss: 0.07537
# Epoch 4, age val loss: 0.01933, gender val loss: 0.02761, ethnicity val loss: 0.03591
# Epoch 5, val loss: 0.08430, train loss: 0.06813
# Epoch 5, age val loss: 0.01691, gender val loss: 0.02620, ethnicity val loss: 0.04119
# Epoch 6, val loss: 0.08285 -> 0.07970, train loss: 0.06085
# Epoch 6, age val loss: 0.01622, gender val loss: 0.02877, ethnicity val loss: 0.03471
# Epoch 7, val loss: 0.08190, train loss: 0.05351
# Epoch 7, age val loss: 0.01634, gender val loss: 0.02758, ethnicity val loss: 0.03798
# Epoch 8, val loss: 0.11537, train loss: 0.04844
# Epoch 8, age val loss: 0.01810, gender val loss: 0.06200, ethnicity val loss: 0.03527
# Epoch 9, val loss: 0.11095, train loss: 0.04201
# Epoch 9, age val loss: 0.01949, gender val loss: 0.05305, ethnicity val loss: 0.03841
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.02656, train loss: 0.03691
# Epoch 1, val loss: 0.02656 -> 0.01971, train loss: 0.02376
# Epoch 2, val loss: 0.01971 -> 0.01918, train loss: 0.01976
# Epoch 3, val loss: 0.01918 -> 0.01709, train loss: 0.01785
# Epoch 4, val loss: 0.01709 -> 0.01700, train loss: 0.01663
# Epoch 5, val loss: 0.01700 -> 0.01609, train loss: 0.01543
# Epoch 6, val loss: 0.01634, train loss: 0.01439
# Epoch 7, val loss: 0.01741, train loss: 0.01370
# Epoch 8, val loss: 0.01807, train loss: 0.01257
# Epoch 9, val loss: 0.01786, train loss: 0.01181
#
# --------------------------------- Prune 80 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.09929, train loss: 0.15471
# Epoch 0, age val loss: 0.02574, gender val loss: 0.03157, ethnicity val loss: 0.04199
# Epoch 1, val loss: 0.10557, train loss: 0.11020
# Epoch 1, age val loss: 0.03085, gender val loss: 0.03180, ethnicity val loss: 0.04292
# Epoch 2, val loss: 0.10943, train loss: 0.09556
# Epoch 2, age val loss: 0.03496, gender val loss: 0.03119, ethnicity val loss: 0.04329
# Epoch 3, val loss: 0.09929 -> 0.07513, train loss: 0.08553
# Epoch 3, age val loss: 0.01680, gender val loss: 0.02449, ethnicity val loss: 0.03385
# Epoch 4, val loss: 0.07743, train loss: 0.07720
# Epoch 4, age val loss: 0.01618, gender val loss: 0.02431, ethnicity val loss: 0.03694
# Epoch 5, val loss: 0.08260, train loss: 0.06862
# Epoch 5, age val loss: 0.01825, gender val loss: 0.02925, ethnicity val loss: 0.03510
# Epoch 6, val loss: 0.08171, train loss: 0.06060
# Epoch 6, age val loss: 0.01659, gender val loss: 0.03006, ethnicity val loss: 0.03505
# Epoch 7, val loss: 0.08140, train loss: 0.05387
# Epoch 7, age val loss: 0.01638, gender val loss: 0.03015, ethnicity val loss: 0.03487
# Epoch 8, val loss: 0.08074, train loss: 0.04730
# Epoch 8, age val loss: 0.01577, gender val loss: 0.02586, ethnicity val loss: 0.03911
# Epoch 9, val loss: 0.10998, train loss: 0.04212
# Epoch 9, age val loss: 0.01648, gender val loss: 0.04367, ethnicity val loss: 0.04983
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.02354, train loss: 0.03206
# Epoch 1, val loss: 0.02354 -> 0.02055, train loss: 0.02214
# Epoch 2, val loss: 0.02055 -> 0.01934, train loss: 0.02001
# Epoch 3, val loss: 0.01934 -> 0.01804, train loss: 0.01873
# Epoch 4, val loss: 0.01804 -> 0.01750, train loss: 0.01770
# Epoch 5, val loss: 0.01770, train loss: 0.01683
# Epoch 6, val loss: 0.01817, train loss: 0.01596
# Epoch 7, val loss: 0.01796, train loss: 0.01548
# Epoch 8, val loss: 0.01862, train loss: 0.01474
# Epoch 9, val loss: 0.01827, train loss: 0.01421
#
# --------------------------------- Prune 90 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.10726, train loss: 0.14924
# Epoch 0, age val loss: 0.03033, gender val loss: 0.02858, ethnicity val loss: 0.04836
# Epoch 1, val loss: 0.10726 -> 0.10667, train loss: 0.10717
# Epoch 1, age val loss: 0.03189, gender val loss: 0.02747, ethnicity val loss: 0.04730
# Epoch 2, val loss: 0.12215, train loss: 0.09308
# Epoch 2, age val loss: 0.03831, gender val loss: 0.02401, ethnicity val loss: 0.05982
# Epoch 3, val loss: 0.10667 -> 0.07856, train loss: 0.08526
# Epoch 3, age val loss: 0.01673, gender val loss: 0.02600, ethnicity val loss: 0.03583
# Epoch 4, val loss: 0.09257, train loss: 0.07406
# Epoch 4, age val loss: 0.02885, gender val loss: 0.03049, ethnicity val loss: 0.03323
# Epoch 5, val loss: 0.08073, train loss: 0.06638
# Epoch 5, age val loss: 0.01569, gender val loss: 0.02956, ethnicity val loss: 0.03548
# Epoch 6, val loss: 0.08418, train loss: 0.06010
# Epoch 6, age val loss: 0.01819, gender val loss: 0.03362, ethnicity val loss: 0.03236
# Epoch 7, val loss: 0.08129, train loss: 0.05292
# Epoch 7, age val loss: 0.01557, gender val loss: 0.02771, ethnicity val loss: 0.03801
# Epoch 8, val loss: 0.08903, train loss: 0.04638
# Epoch 8, age val loss: 0.01488, gender val loss: 0.03770, ethnicity val loss: 0.03646
# Epoch 9, val loss: 0.09958, train loss: 0.04278
# Epoch 9, age val loss: 0.02930, gender val loss: 0.03338, ethnicity val loss: 0.03690
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.04336, train loss: 0.04331
# Epoch 1, val loss: 0.04336 -> 0.04331, train loss: 0.04330
# Epoch 2, val loss: 0.04332, train loss: 0.04330
# Epoch 3, val loss: 0.04334, train loss: 0.04330
# Epoch 4, val loss: 0.04331 -> 0.04331, train loss: 0.04331
# Epoch 5, val loss: 0.04334, train loss: 0.04330
# Epoch 6, val loss: 0.04331 -> 0.04330, train loss: 0.04330
# Epoch 7, val loss: 0.04331, train loss: 0.04330
# Epoch 8, val loss: 0.04332, train loss: 0.04330
# Epoch 9, val loss: 0.04330, train loss: 0.04330

# %% [markdown]
# #### Ethnicity

# %%
task = 'ethnicity'
num_epochs = 10
            
for i in range(10):
    print(f'--------------------------------- Prune {i*10} % ---------------------------------')
    prune_pct = 1.0*i / 10
    scores, mean_lat, std_lat = pruned_mtl_training(task, prune_pct, num_epochs, train_loader, val_loader, val_dataset)
    print()
# Out:
# --------------------------------- Prune 0 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.13343, train loss: 0.15908
# Epoch 0, age val loss: 0.04161, gender val loss: 0.03293, ethnicity val loss: 0.05889
# Epoch 1, val loss: 0.13343 -> 0.08776, train loss: 0.11325
# Epoch 1, age val loss: 0.02020, gender val loss: 0.02702, ethnicity val loss: 0.04054
# Epoch 2, val loss: 0.08776 -> 0.08263, train loss: 0.09784
# Epoch 2, age val loss: 0.01873, gender val loss: 0.02643, ethnicity val loss: 0.03747
# Epoch 3, val loss: 0.08794, train loss: 0.08632
# Epoch 3, age val loss: 0.02303, gender val loss: 0.02370, ethnicity val loss: 0.04121
# Epoch 4, val loss: 0.08263 -> 0.07545, train loss: 0.07766
# Epoch 4, age val loss: 0.01611, gender val loss: 0.02358, ethnicity val loss: 0.03576
# Epoch 5, val loss: 0.08459, train loss: 0.06985
# Epoch 5, age val loss: 0.01778, gender val loss: 0.02727, ethnicity val loss: 0.03953
# Epoch 6, val loss: 0.08923, train loss: 0.06169
# Epoch 6, age val loss: 0.01881, gender val loss: 0.02780, ethnicity val loss: 0.04262
# Epoch 7, val loss: 0.08499, train loss: 0.05420
# Epoch 7, age val loss: 0.01731, gender val loss: 0.03317, ethnicity val loss: 0.03451
# Epoch 8, val loss: 0.09069, train loss: 0.04892
# Epoch 8, age val loss: 0.01547, gender val loss: 0.03502, ethnicity val loss: 0.04021
# Epoch 9, val loss: 0.08307, train loss: 0.04259
# Epoch 9, age val loss: 0.01726, gender val loss: 0.02367, ethnicity val loss: 0.04214
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.03520, train loss: 0.03598
# Epoch 1, val loss: 0.03539, train loss: 0.03042
# Epoch 2, val loss: 0.03669, train loss: 0.02562
# Epoch 3, val loss: 0.03669, train loss: 0.02215
# Epoch 4, val loss: 0.04395, train loss: 0.01833
# Epoch 5, val loss: 0.04157, train loss: 0.01550
# Epoch 6, val loss: 0.05130, train loss: 0.01288
# Epoch 7, val loss: 0.04553, train loss: 0.01152
# Epoch 8, val loss: 0.04465, train loss: 0.00947
# Epoch 9, val loss: 0.04718, train loss: 0.00887
#
# --------------------------------- Prune 10 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.11097, train loss: 0.15283
# Epoch 0, age val loss: 0.02567, gender val loss: 0.03697, ethnicity val loss: 0.04833
# Epoch 1, val loss: 0.11097 -> 0.09719, train loss: 0.10771
# Epoch 1, age val loss: 0.02130, gender val loss: 0.02865, ethnicity val loss: 0.04724
# Epoch 2, val loss: 0.09719 -> 0.08081, train loss: 0.09421
# Epoch 2, age val loss: 0.01941, gender val loss: 0.02456, ethnicity val loss: 0.03683
# Epoch 3, val loss: 0.08081 -> 0.07928, train loss: 0.08285
# Epoch 3, age val loss: 0.01666, gender val loss: 0.02702, ethnicity val loss: 0.03560
# Epoch 4, val loss: 0.10236, train loss: 0.07595
# Epoch 4, age val loss: 0.02612, gender val loss: 0.02555, ethnicity val loss: 0.05069
# Epoch 5, val loss: 0.08322, train loss: 0.06672
# Epoch 5, age val loss: 0.02200, gender val loss: 0.02717, ethnicity val loss: 0.03405
# Epoch 6, val loss: 0.07928 -> 0.07846, train loss: 0.06072
# Epoch 6, age val loss: 0.01840, gender val loss: 0.02484, ethnicity val loss: 0.03522
# Epoch 7, val loss: 0.08356, train loss: 0.05396
# Epoch 7, age val loss: 0.01962, gender val loss: 0.02875, ethnicity val loss: 0.03520
# Epoch 8, val loss: 0.09253, train loss: 0.04714
# Epoch 8, age val loss: 0.01846, gender val loss: 0.03593, ethnicity val loss: 0.03814
# Epoch 9, val loss: 0.11215, train loss: 0.04200
# Epoch 9, age val loss: 0.01571, gender val loss: 0.05107, ethnicity val loss: 0.04536
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.03479, train loss: 0.02893
# Epoch 1, val loss: 0.03689, train loss: 0.02503
# Epoch 2, val loss: 0.03479 -> 0.03474, train loss: 0.02155
# Epoch 3, val loss: 0.03733, train loss: 0.01814
# Epoch 4, val loss: 0.03992, train loss: 0.01559
# Epoch 5, val loss: 0.04843, train loss: 0.01351
# Epoch 6, val loss: 0.04304, train loss: 0.01190
# Epoch 7, val loss: 0.04221, train loss: 0.00970
# Epoch 8, val loss: 0.04471, train loss: 0.00857
# Epoch 9, val loss: 0.05509, train loss: 0.00775
#
# --------------------------------- Prune 20 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.10466, train loss: 0.15526
# Epoch 0, age val loss: 0.02460, gender val loss: 0.03119, ethnicity val loss: 0.04886
# Epoch 1, val loss: 0.10981, train loss: 0.11017
# Epoch 1, age val loss: 0.02001, gender val loss: 0.03871, ethnicity val loss: 0.05109
# Epoch 2, val loss: 0.10466 -> 0.08769, train loss: 0.09410
# Epoch 2, age val loss: 0.01940, gender val loss: 0.03057, ethnicity val loss: 0.03771
# Epoch 3, val loss: 0.08769 -> 0.08727, train loss: 0.08331
# Epoch 3, age val loss: 0.01847, gender val loss: 0.03050, ethnicity val loss: 0.03830
# Epoch 4, val loss: 0.10436, train loss: 0.07504
# Epoch 4, age val loss: 0.01748, gender val loss: 0.05111, ethnicity val loss: 0.03577
# Epoch 5, val loss: 0.08727 -> 0.07913, train loss: 0.06895
# Epoch 5, age val loss: 0.01679, gender val loss: 0.02560, ethnicity val loss: 0.03674
# Epoch 6, val loss: 0.08370, train loss: 0.05891
# Epoch 6, age val loss: 0.01631, gender val loss: 0.02495, ethnicity val loss: 0.04244
# Epoch 7, val loss: 0.08205, train loss: 0.05520
# Epoch 7, age val loss: 0.01748, gender val loss: 0.02716, ethnicity val loss: 0.03740
# Epoch 8, val loss: 0.08992, train loss: 0.04490
# Epoch 8, age val loss: 0.01636, gender val loss: 0.03776, ethnicity val loss: 0.03580
# Epoch 9, val loss: 0.08833, train loss: 0.04058
# Epoch 9, age val loss: 0.01652, gender val loss: 0.03433, ethnicity val loss: 0.03748
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0
# Epoch 4, age val loss: 0.02335, gender val loss: 0.02285, ethnicity val loss: 0.04078
# Epoch 5, val loss: 0.10570, train loss: 0.06741
# Epoch 5, age val loss: 0.02983, gender val loss: 0.03006, ethnicity val loss: 0.04581
# Epoch 6, val loss: 0.08508 -> 0.07651, train loss: 0.06171
# Epoch 6, age val loss: 0.01588, gender val loss: 0.02694, ethnicity val loss: 0.03369
# Epoch 7, val loss: 0.07752, train loss: 0.05315
# Epoch 7, age val loss: 0.01608, gender val loss: 0.02815, ethnicity val loss: 0.03330
# Epoch 8, val loss: 0.08837, train loss: 0.04831
# Epoch 8, age val loss: 0.01677, gender val loss: 0.03027, ethnicity val loss: 0.04132
# Epoch 9, val loss: 0.08649, train loss: 0.04157
# Epoch 9, age val loss: 0.01637, gender val loss: 0.03008, ethnicity val loss: 0.04004
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.03603, train loss: 0.04305
# Epoch 1, val loss: 0.03805, train loss: 0.03261
# Epoch 2, val loss: 0.03816, train loss: 0.02756
# Epoch 3, val loss: 0.03603 -> 0.03501, train loss: 0.02266
# Epoch 4, val loss: 0.04832, train loss: 0.01973
# Epoch 5, val loss: 0.04454, train loss: 0.01679
# Epoch 6, val loss: 0.04585, train loss: 0.01360
# Epoch 7, val loss: 0.04606, train loss: 0.01255
# Epoch 8, val loss: 0.05327, train loss: 0.01072
# Epoch 9, val loss: 0.05280, train loss: 0.00925
#
# --------------------------------- Prune 50 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.11949, train loss: 0.15443
# Epoch 0, age val loss: 0.02837, gender val loss: 0.03243, ethnicity val loss: 0.05870
# Epoch 1, val loss: 0.11949 -> 0.10275, train loss: 0.11050
# Epoch 1, age val loss: 0.02020, gender val loss: 0.03879, ethnicity val loss: 0.04376
# Epoch 2, val loss: 0.10275 -> 0.08476, train loss: 0.09576
# Epoch 2, age val loss: 0.02012, gender val loss: 0.02523, ethnicity val loss: 0.03941
# Epoch 3, val loss: 0.08476 -> 0.08164, train loss: 0.08529
# Epoch 3, age val loss: 0.01687, gender val loss: 0.02478, ethnicity val loss: 0.03999
# Epoch 4, val loss: 0.08448, train loss: 0.07746
# Epoch 4, age val loss: 0.02099, gender val loss: 0.02486, ethnicity val loss: 0.03863
# Epoch 5, val loss: 0.08164 -> 0.07822, train loss: 0.06651
# Epoch 5, age val loss: 0.01497, gender val loss: 0.02867, ethnicity val loss: 0.03457
# Epoch 6, val loss: 0.08615, train loss: 0.06200
# Epoch 6, age val loss: 0.01927, gender val loss: 0.02662, ethnicity val loss: 0.04026
# Epoch 7, val loss: 0.07822 -> 0.07464, train loss: 0.05300
# Epoch 7, age val loss: 0.01587, gender val loss: 0.02358, ethnicity val loss: 0.03518
# Epoch 8, val loss: 0.08125, train loss: 0.04688
# Epoch 8, age val loss: 0.01650, gender val loss: 0.02687, ethnicity val loss: 0.03788
# Epoch 9, val loss: 0.09812, train loss: 0.04187
# Epoch 9, age val loss: 0.02254, gender val loss: 0.03752, ethnicity val loss: 0.03806
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.04437, train loss: 0.06225
# Epoch 1, val loss: 0.04437 -> 0.04095, train loss: 0.04496
# Epoch 2, val loss: 0.04095 -> 0.03775, train loss: 0.03864
# Epoch 3, val loss: 0.03786, train loss: 0.03452
# Epoch 4, val loss: 0.03805, train loss: 0.03063
# Epoch 5, val loss: 0.03775 -> 0.03767, train loss: 0.02658
# Epoch 6, val loss: 0.03848, train loss: 0.02329
# Epoch 7, val loss: 0.04511, train loss: 0.02041
# Epoch 8, val loss: 0.03973, train loss: 0.01798
# Epoch 9, val loss: 0.04819, train loss: 0.01504
#
# --------------------------------- Prune 60 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.10279, train loss: 0.15270
# Epoch 0, age val loss: 0.02389, gender val loss: 0.03523, ethnicity val loss: 0.04367
# Epoch 1, val loss: 0.10279 -> 0.09509, train loss: 0.11100
# Epoch 1, age val loss: 0.02400, gender val loss: 0.02886, ethnicity val loss: 0.04223
# Epoch 2, val loss: 0.09509 -> 0.09115, train loss: 0.09441
# Epoch 2, age val loss: 0.02717, gender val loss: 0.02522, ethnicity val loss: 0.03876
# Epoch 3, val loss: 0.09115 -> 0.08021, train loss: 0.08437
# Epoch 3, age val loss: 0.01731, gender val loss: 0.02363, ethnicity val loss: 0.03927
# Epoch 4, val loss: 0.08750, train loss: 0.07575
# Epoch 4, age val loss: 0.01719, gender val loss: 0.03166, ethnicity val loss: 0.03865
# Epoch 5, val loss: 0.08167, train loss: 0.06795
# Epoch 5, age val loss: 0.01801, gender val loss: 0.02817, ethnicity val loss: 0.03550
# Epoch 6, val loss: 0.08283, train loss: 0.06101
# Epoch 6, age val loss: 0.01954, gender val loss: 0.02715, ethnicity val loss: 0.03614
# Epoch 7, val loss: 0.08075, train loss: 0.05493
# Epoch 7, age val loss: 0.01561, gender val loss: 0.03134, ethnicity val loss: 0.03380
# Epoch 8, val loss: 0.10373, train loss: 0.04996
# Epoch 8, age val loss: 0.02129, gender val loss: 0.03381, ethnicity val loss: 0.04863
# Epoch 9, val loss: 0.08923, train loss: 0.04188
# Epoch 9, age val loss: 0.01685, gender val loss: 0.03143, ethnicity val loss: 0.04095
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.04597, train loss: 0.06216
# Epoch 1, val loss: 0.04597 -> 0.04266, train loss: 0.04790
# Epoch 2, val loss: 0.04266 -> 0.04034, train loss: 0.04296
# Epoch 3, val loss: 0.04332, train loss: 0.03915
# Epoch 4, val loss: 0.04336, train loss: 0.03603
# Epoch 5, val loss: 0.04034 -> 0.03868, train loss: 0.03330
# Epoch 6, val loss: 0.03972, train loss: 0.03046
# Epoch 7, val loss: 0.03868 -> 0.03765, train loss: 0.02782
# Epoch 8, val loss: 0.04119, train loss: 0.02538
# Epoch 9, val loss: 0.04308, train loss: 0.02290
#
# --------------------------------- Prune 70 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.10394, train loss: 0.15534
# Epoch 0, age val loss: 0.02843, gender val loss: 0.02982, ethnicity val loss: 0.04569
# Epoch 1, val loss: 0.10394 -> 0.09806, train loss: 0.11015
# Epoch 1, age val loss: 0.02247, gender val loss: 0.03047, ethnicity val loss: 0.04512
# Epoch 2, val loss: 0.09806 -> 0.08533, train loss: 0.09449
# Epoch 2, age val loss: 0.02331, gender val loss: 0.02426, ethnicity val loss: 0.03776
# Epoch 3, val loss: 0.09888, train loss: 0.08349
# Epoch 3, age val loss: 0.03457, gender val loss: 0.02684, ethnicity val loss: 0.03747
# Epoch 4, val loss: 0.08533 -> 0.08361, train loss: 0.07455
# Epoch 4, age val loss: 0.01599, gender val loss: 0.03157, ethnicity val loss: 0.03606
# Epoch 5, val loss: 0.08361 -> 0.07647, train loss: 0.06720
# Epoch 5, age val loss: 0.01659, gender val loss: 0.02433, ethnicity val loss: 0.03555
# Epoch 6, val loss: 0.08177, train loss: 0.05926
# Epoch 6, age val loss: 0.02085, gender val loss: 0.02690, ethnicity val loss: 0.03402
# Epoch 7, val loss: 0.07727, train loss: 0.05353
# Epoch 7, age val loss: 0.01810, gender val loss: 0.02601, ethnicity val loss: 0.03316
# Epoch 8, val loss: 0.08094, train loss: 0.04719
# Epoch 8, age val loss: 0.01887, gender val loss: 0.02580, ethnicity val loss: 0.03626
# Epoch 9, val loss: 0.09040, train loss: 0.04029
# Epoch 9, age val loss: 0.01730, gender val loss: 0.03433, ethnicity val loss: 0.03876
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.06241, train loss: 0.07821
# Epoch 1, val loss: 0.06241 -> 0.05062, train loss: 0.05955
# Epoch 2, val loss: 0.05062 -> 0.04747, train loss: 0.05135
# Epoch 3, val loss: 0.04779, train loss: 0.04752
# Epoch 4, val loss: 0.04747 -> 0.04322, train loss: 0.04429
# Epoch 5, val loss: 0.04322 -> 0.04231, train loss: 0.04204
# Epoch 6, val loss: 0.04231 -> 0.04185, train loss: 0.03967
# Epoch 7, val loss: 0.04187, train loss: 0.03749
# Epoch 8, val loss: 0.04451, train loss: 0.03522
# Epoch 9, val loss: 0.04185 -> 0.04167, train loss: 0.03363
#
# --------------------------------- Prune 80 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.10975, train loss: 0.15434
# Epoch 0, age val loss: 0.02554, gender val loss: 0.03534, ethnicity val loss: 0.04887
# Epoch 1, val loss: 0.10975 -> 0.10632, train loss: 0.11043
# Epoch 1, age val loss: 0.02532, gender val loss: 0.03087, ethnicity val loss: 0.05013
# Epoch 2, val loss: 0.10632 -> 0.08927, train loss: 0.09511
# Epoch 2, age val loss: 0.02219, gender val loss: 0.02971, ethnicity val loss: 0.03737
# Epoch 3, val loss: 0.08927 -> 0.08058, train loss: 0.08271
# Epoch 3, age val loss: 0.01642, gender val loss: 0.02808, ethnicity val loss: 0.03607
# Epoch 4, val loss: 0.08058 -> 0.07832, train loss: 0.07613
# Epoch 4, age val loss: 0.01869, gender val loss: 0.02356, ethnicity val loss: 0.03607
# Epoch 5, val loss: 0.07876, train loss: 0.06654
# Epoch 5, age val loss: 0.01806, gender val loss: 0.02677, ethnicity val loss: 0.03393
# Epoch 6, val loss: 0.08290, train loss: 0.06101
# Epoch 6, age val loss: 0.01894, gender val loss: 0.02619, ethnicity val loss: 0.03777
# Epoch 7, val loss: 0.09106, train loss: 0.05263
# Epoch 7, age val loss: 0.01520, gender val loss: 0.03670, ethnicity val loss: 0.03916
# Epoch 8, val loss: 0.08224, train loss: 0.04772
# Epoch 8, age val loss: 0.01579, gender val loss: 0.02586, ethnicity val loss: 0.04059
# Epoch 9, val loss: 0.08968, train loss: 0.04064
# Epoch 9, age val loss: 0.01732, gender val loss: 0.03343, ethnicity val loss: 0.03893
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.06894, train loss: 0.07928
# Epoch 1, val loss: 0.06894 -> 0.05691, train loss: 0.06472
# Epoch 2, val loss: 0.05873, train loss: 0.05686
# Epoch 3, val loss: 0.05691 -> 0.05204, train loss: 0.05230
# Epoch 4, val loss: 0.05204 -> 0.04927, train loss: 0.04974
# Epoch 5, val loss: 0.04927 -> 0.04914, train loss: 0.04799
# Epoch 6, val loss: 0.04914 -> 0.04697, train loss: 0.04624
# Epoch 7, val loss: 0.04787, train loss: 0.04512
# Epoch 8, val loss: 0.04914, train loss: 0.04392
# Epoch 9, val loss: 0.04942, train loss: 0.04268
#
# --------------------------------- Prune 90 % ---------------------------------
# ---------------- Train Initial Model ----------------
# Epoch 0, val loss: inf -> 0.13168, train loss: 0.15665
# Epoch 0, age val loss: 0.03656, gender val loss: 0.03481, ethnicity val loss: 0.06031
# Epoch 1, val loss: 0.13168 -> 0.10027, train loss: 0.11013
# Epoch 1, age val loss: 0.02577, gender val loss: 0.02716, ethnicity val loss: 0.04734
# Epoch 2, val loss: 0.10027 -> 0.09335, train loss: 0.09511
# Epoch 2, age val loss: 0.02025, gender val loss: 0.03013, ethnicity val loss: 0.04297
# Epoch 3, val loss: 0.09335 -> 0.08740, train loss: 0.08545
# Epoch 3, age val loss: 0.02229, gender val loss: 0.02874, ethnicity val loss: 0.03636
# Epoch 4, val loss: 0.08862, train loss: 0.07589
# Epoch 4, age val loss: 0.01834, gender val loss: 0.02412, ethnicity val loss: 0.04617
# Epoch 5, val loss: 0.08740 -> 0.08404, train loss: 0.06895
# Epoch 5, age val loss: 0.01995, gender val loss: 0.03135, ethnicity val loss: 0.03273
# Epoch 6, val loss: 0.08404 -> 0.07871, train loss: 0.06055
# Epoch 6, age val loss: 0.01720, gender val loss: 0.02641, ethnicity val loss: 0.03509
# Epoch 7, val loss: 0.09172, train loss: 0.05479
# Epoch 7, age val loss: 0.02369, gender val loss: 0.02946, ethnicity val loss: 0.03858
# Epoch 8, val loss: 0.08515, train loss: 0.04817
# Epoch 8, age val loss: 0.01717, gender val loss: 0.02971, ethnicity val loss: 0.03828
# Epoch 9, val loss: 0.08498, train loss: 0.04242
# Epoch 9, age val loss: 0.02130, gender val loss: 0.02844, ethnicity val loss: 0.03523
# -------------- Fine-tuning Pruned Model -------------
# Epoch 0, val loss: inf -> 0.07709, train loss: 0.08578
# Epoch 1, val loss: 0.07709 -> 0.07611, train loss: 0.07852
# Epoch 2, val loss: 0.07611 -> 0.07153, train loss: 0.07515
# Epoch 3, val loss: 0.07153 -> 0.07014, train loss: 0.07349
# Epoch 4, val loss: 0.07014 -> 0.06916, train loss: 0.07254
# Epoch 5, val loss: 0.07067, train loss: 0.07142
# Epoch 6, val loss: 0.06916 -> 0.06623, train loss: 0.07065
# Epoch 7, val loss: 0.06706, train loss: 0.06966
# Epoch 8, val loss: 0.06623 -> 0.06547, train loss: 0.06905
# Epoch 9, val loss: 0.06954, train loss: 0.06822
